# %% [markdown]
# **LAB EXPERIMENT - 2**\
# **Regression and Optimization (Linear and Logistic regression)**
#
# Name : Poovika M\
# Roll No : 24BAD087

# %% [markdown]
# **SCENARIO 1**
#
# **CODE INTERPRETATION**
#
#  1. Import Libraries
#
#     Libraries are imported for:
#
#     Data handling (pandas, numpy)
#
#     Visualization (matplotlib)
#
#     Machine learning models and evaluation (sklearn)
#
#  2. Load Dataset
#
#     The file bottle.csv is loaded into a DataFrame.
#
#  3. Select Features & Target
#
#     Selected input features:
#
#     Depthm
#
#     Salnty
#
#     O2ml_L
#
#     Target variable:
#
#     T_degC (Temperature)
#
#     Only required columns are kept.
#
#  4. Handle Missing Values
#
#     Missing values are removed using dropna() to ensure clean data for training.
#
#  5. Split Features and Target
#
#     X → Input features
#
#     y → Target variable (Temperature)
#
#  6. Feature Scaling
#
#     StandardScaler is applied to standardize feature values so all inputs are on the same scale.
#
#  7. Train-Test Split
#
#     The dataset is split into:
#
#     80% training data
#
#     20% testing data
#
#  8. Train Linear Regression Model
#
#     A Linear Regression model is trained using training data.
#
#  9. Prediction
#
#     The model predicts temperature values for the test data.
#
#  10. Model Evaluation
#
#      Performance is measured using:
#
#     MSE (Mean Squared Error)
#
#     RMSE (Root Mean Squared Error)
#
#     R² Score → Indicates how well the model explains variance
#
#  11. Visualization
#
#     Actual vs Predicted Plot → Shows how close predictions are to real values.
#
#     Residual Plot → Shows error distribution (should be randomly scattered around 0).
#
#  12. Ridge Regression
#
#       Ridge model (with regularization) is trained and its R² score is calculated.
#
#  13. Lasso Regression
#
#       Lasso model is trained and its R² score is calculated.
#
#  14. Conclusion
#
#       The program compares Linear Regression, Ridge, and Lasso models to predict temperature and evaluates their performance using error metrics and R² score.

# %%
#POOVIKA M - 24BAD087
# SCENARIO 1: LINEAR REGRESSION
print("POOVIKA M - 24BAD087")
# 1. Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score

# 2. Load dataset
data = pd.read_csv("/bottle.csv", low_memory=False)

# 3. Select ONLY existing columns (no latitude / longitude)
features = ['Depthm', 'Salnty', 'O2ml_L']
target = 'T_degC'

df = data[features + [target]].copy()

# 4. Remove missing values (safe & simple)
df.dropna(inplace=True)

# 5. Split features and target
X = df[features]
y = df[target]

# 6. Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 7. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 8. Train Linear Regression
model = LinearRegression()
model.fit(X_train, y_train)

# 9. Predictions
y_pred = model.predict(X_test)

# 10. Evaluation
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("LINEAR REGRESSION RESULTS")
print("MSE :", mse)
print("RMSE:", rmse)
print("R²  :", r2)

# 11. Actual vs Predicted plot
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Temperature (T_degC)")
plt.ylabel("Predicted Temperature")
plt.title("Actual vs Predicted Temperature")
plt.show()

# 12. Residual plot
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.axhline(0)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# 13. Ridge Regression
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
ridge_pred = ridge.predict(X_test)
print("Ridge R²:", r2_score(y_test, ridge_pred))

# 14. Lasso Regression
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)
lasso_pred = lasso.predict(X_test)
print("Lasso R²:", r2_score(y_test, lasso_pred))
# Out:
# POOVIKA M - 24BAD087
# LINEAR REGRESSION RESULTS
# MSE : 3.79098173615453
# RMSE: 1.9470443590618396
# R²  : 0.7876170657606347
# Ridge R²: 0.7876170446099516
# Lasso R²: 0.7874996600741913

# %% [markdown]
# **SCENARIO 2**
#
# **CODE INTERPRETATION**
#
#  1. Import Libraries
#
#     Libraries are imported for:
#
#     Data handling (pandas, numpy)
#
#     Visualization (matplotlib, seaborn)
#
#     Model building & evaluation (sklearn)
#
#  2. Load Dataset
#
#     The LIC 10-minute stock data is loaded into a DataFrame.
# Column names are converted to lowercase and cleaned for easy access.
#
#  3. Identify Required Columns
#
#     Relevant columns are automatically selected:
#
#     Open price
#
#     Close/LTP price
#
#     High price
#
#     Low price
#
#     Volume
#
#  4. Create Target Variable
#
#     A new column price_movement is created:
#
#     1 → If Close price > Open price (Price Increased)
#
#     0 → If Close price ≤ Open price (Price Decreased)
#
#     This converts the problem into a binary classification task.
#
#  5. Select Features & Target
#
#     Features (X): Open, High, Low, Volume
#
#     Target (y): Price movement (0 or 1)
#
#     Missing values are replaced with column mean.
#
#  6. Feature Scaling
#
#     StandardScaler is applied to standardize feature values.
#
#  7. Train-Test Split
#
#     Data is split into:
#
#     80% training data
#
#     20% testing data
#
#  8. Train Logistic Regression Model
#
#     A Logistic Regression model is trained to classify price movement.
#
#  9. Prediction
#
#     The model predicts:
#
#     Class labels (0 or 1)
#
#     Probability of price increase
#
#  10. Model Evaluation
#
#       Performance is evaluated using:
#
#     Accuracy
#
#     Precision
#
#     Recall
#
#     F1 Score
#
#  11. Confusion Matrix
#
#       A heatmap is plotted to show correct and incorrect classifications.
#
#  12. ROC Curve
#
#     ROC curve is plotted to evaluate classification performance.
#     AUC value shows how well the model distinguishes between classes.
#
#  13. Feature Importance
#
#       Model coefficients are plotted to show which features most influence price movement.
#
#  14. Conclusion
#
#       The program uses Logistic Regression to predict stock price movement and evaluates its performance using classification metrics and visualizations.

# %%
#POOVIKA M - 24BAD087
#SCENARIO 2: SIMPLE LOGISTIC REGRESSION (LIC)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, roc_curve, auc
)

path=r"/LICI - 10 minute data.csv"
data = pd.read_csv(path)

data.columns = data.columns.str.strip().str.lower()

open_col  = [c for c in data.columns if 'open' in c][0]
close_col = [c for c in data.columns if 'close' in c or 'ltp' in c][0]
high_col  = [c for c in data.columns if 'high' in c][0]
low_col   = [c for c in data.columns if 'low' in c][0]
vol_col   = [c for c in data.columns if 'vol' in c][0]

data['price_movement'] = np.where(
    data[close_col] > data[open_col], 1, 0
)

features = [open_col, high_col, low_col, vol_col]
X = data[features]
y = data['price_movement']

# Handle missing values
X.fillna(X.mean(), inplace=True)

# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Train Logistic Regression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# Evaluation
print("LOGISTIC REGRESSION RESULTS")
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], '--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Feature Importance
importance = pd.Series(
    model.coef_[0], index=features
).sort_values()

importance.plot(kind='barh')
plt.title("Feature Importance")
plt.show()
# Out:
# /tmp/ipython-input-267955038.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.fillna(X.mean(), inplace=True)
# LOGISTIC REGRESSION RESULTS
# Accuracy : 0.6132971506105834
# Precision: 1.0
# Recall   : 0.030612244897959183
# F1 Score : 0.0594059405940594
